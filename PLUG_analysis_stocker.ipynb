# %%
from stocker import Stocker
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plug = Stocker('PLUG')
### Uses data from quandl
# Out:
# PLUG Stocker Initialized. Data covers 1999-10-29 00:00:00 to 2018-03-27 00:00:00.

# %%
stock_history = plug.stock

# %% [markdown]
# #### The data is only from 1999 to 2018. This analysis is done in November 2020, so this data is not updated. The current price is around 26 dollars, so this data would not be appropriate for any kind of predictions.

# %% [markdown]
# # Exploratory Data Analysis

# %%
stock_history.head()
# Out:
#         Date   Open   High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
# 0 1999-10-29  15.75  19.69  15.00  16.00  5426000.0          0.0          1.0
# 1 1999-11-01  16.75  16.75  15.00  16.00  1506000.0          0.0          1.0
# 2 1999-11-02  16.44  20.00  16.38  17.88  1701000.0          0.0          1.0
# 3 1999-11-03  18.88  19.31  18.13  18.63   683000.0          0.0          1.0
# 4 1999-11-04  19.44  19.88  18.63  19.06   480000.0          0.0          1.0
#
#    Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume         ds      y  \
# 0      157.5      196.9     150.0       160.0     542600.0 1999-10-29  160.0
# 1      167.5      167.5     150.0       160.0     150600.0 1999-11-01  160.0
# 2      164.4      200.0     163.8       178.8     170100.0 1999-11-02  178.8
# 3      188.8      193.1     181.3       186.3      68300.0 1999-11-03  186.3
# 4      194.4      198.8     186.3       190.6      48000.0 1999-11-04  190.6
#
#    Daily Change
# 0           2.5
# ...

# %%
plug.plot_stock()
# Out:
# Maximum Adj. Close = 1498.00 on 2000-03-10 00:00:00.
# Minimum Adj. Close = 0.12 on 2013-02-26 00:00:00.
# Current Adj. Close = 1.89 on 2018-03-27 00:00:00.

# %%
model, model_data = plug.create_prophet_model()

# %%
model.plot_components(model_data)
plt.show()

# %% [markdown]
# #### This is the monthly and yearly trends
